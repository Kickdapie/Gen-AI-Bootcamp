# %% [markdown]
# # Connect an SQLAlchemy application to Neon
#
# https://neon.tech/docs/guides/sqlalchemy
#
# Code:
#
# https://neon.tech/docs/guides/sqlalchemy#create-an-sqlalchemy-engine-for-your-neon-project

# %%
from sqlalchemy import create_engine

# %% [markdown]
# # Establishing Connectivity - the Engine
#
# https://docs.sqlalchemy.org/en/20/tutorial/engine.html

# %% [markdown]
# ### Get the Connection String
#
# Create a new project: https://console.neon.tech/app/projects/
#
# Select the new project, and go to Dashboad and copy connection string from here:
#
# ![Where to Copy Connection String From](connection_string.png)

# %%
# psql 'postgresql://k191612:3AueMsX1OSYt@ep-curly-mouse-38234397.us-east-2.aws.neon.tech/test1?sslmode=require'

# conn_str = f'postgresql://ziaukhan:abcdefghijklmnopqrst@ep-little-frog-313391.us-east-2.aws.neon.tech/neondb?sslmode=require'
conn_str = f'postgresql://k191612:3AueMsX1OSYt@ep-curly-mouse-38234397.us-east-2.aws.neon.tech/test1?sslmode=require'

# %%
from sqlalchemy.engine.base import Engine

engine: Engine = create_engine(conn_str)

# %% [markdown]
# # Getting a Connection
#
# https://docs.sqlalchemy.org/en/20/tutorial/dbapi_transactions.html#getting-a-connection

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("select 'hello world'"))
    print(result.all())
# Out:
# [('hello world',)]

# %% [markdown]
# # My Own Code

# %%
import psycopg2

# Optional: tell psycopg2 to cancel the query on Ctrl-C
import psycopg2.extras; psycopg2.extensions.set_wait_callback(psycopg2.extras.wait_select)

# You can set the password to None if it is specified in a ~/.pgpass file
USERNAME = "alex"
PASSWORD = "AbC123dEf"
HOST = "@ep-cool-darkness-123456.us-east-2.aws.neon.tech"
PORT = "5432"
PROJECT = "dbname"

conn_str = f"dbname={PROJECT} user={USERNAME} password={PASSWORD} host={HOST} port={PORT} sslmode=require"

conn = psycopg2.connect(conn_str)

with conn.cursor() as cur:
 cur.execute("SELECT 'hello neon';")
 print(cur.fetchall())

# %%
from sqlalchemy import create_engine

# USERNAME = "alex"
# PASSWORD = "AbC123dEf"
# HOST = "ep-cool-darkness-123456.us-east-2.aws.neon.tech"
# DATABASE = "dbname"

# conn_str = f'postgresql://{USERNAME}:{PASSWORD}@{HOST}/{DATABASE}?sslmode=require'

conn_str = 'postgresql://spandadb_owner:npg_A0bL2rIVmoqw@ep-crimson-scene-aa30iu0e-pooler.westus3.azure.neon.tech/spandadb?sslmode=require'

engine = create_engine(conn_str)

# %% [markdown]
# # Database Use Case

# %%
from sqlalchemy import create_engine, ForeignKey, Column, String, Integer, CHAR
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

Base = declarative_base()

class Person(Base):
    __tablename__ = 'people'

    ssn = Column('ssn', Integer, primary_key=True)
    firstname = Column('firstname', String)
    lastname = Column('lastname', String)
    gender = Column('gender', CHAR)
    age = Column('age', Integer)

    def __init__(self, ssn, firstname, lastname, gender, age):
        self.ssn = ssn
        self.firstname = firstname
        self.lastname = lastname
        self.gender = gender
        self.age = age

    def __repr__(self):
        return f'{self.ssn} {self.firstname} {self.lastname} {self.gender} {self.age}'

class Thing(Base):
    __tablename__ = 'things'

    tid = Column('tid', Integer, primary_key=True)
    description = Column('description', String)
    owner = Column(Integer, ForeignKey('people.ssn'))

    def __init__(self, tid, description, owner):
        self.tid = tid
        self.description = description
        self.owner = owner

        def __repr__(self):
            return f'{self.tid} {self.description} owned by {self.owner}'

conn_str = 'postgresql://spandadb_owner:npg_A0bL2rIVmoqw@ep-crimson-scene-aa30iu0e-pooler.westus3.azure.neon.tech/spandadb?sslmode=require'
engine = create_engine(conn_str, echo=True)
Base.metadata.create_all(bind=engine)

# Create a function to change the database values
Session = sessionmaker(bind=engine)
session = Session()

# p1 = Person(12345, 'Mike', 'Smith', 'm', 35)
# p2 = Person(54321, 'Gary', 'Farben', 'm', 23)
# p3 = Person(78989, 'Rajesh', 'Abishek', 'm', 54)

# session.add(p1)
# session.add(p2)
# session.add(p3)
# session.commit()

# results = session.query(Person).filter(Person.firstname=='Mike')
# for r in results:
#     print(r.firstname)

t1 = Thing(54321, 'Prius', 12345)
session.add(t1)
session.commit()
# Out:
# /tmp/ipykernel_161991/3636484295.py:5: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# 2025-06-23 20:43:14,804 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-23 20:43:14,806 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-23 20:43:14,897 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-23 20:43:14,899 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-23 20:43:14,993 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-23 20:43:14,995 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-23 20:43:15,089 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-23 20:43:15,095 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# ...
