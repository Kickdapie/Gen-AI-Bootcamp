# %% [markdown]
# # Making an API request

# %%
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

_ : bool = load_dotenv(find_dotenv()) # read local .env file

client : OpenAI = OpenAI()

# %%
from openai.types.chat.chat_completion import ChatCompletion

def chat_completion()->str:
  completion : ChatCompletion = client.chat.completions.create(
    model  = "gpt-3.5-turbo-1106",
    messages= [
      {"role": "system", "content": "You are a software developer, skilled in explaining software concepts with attention to detail."},
      {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
    ]
  )

  return completion.choices[0].message.content

print(chat_completion())
# Out:
# In the realm of code, where logic reigns supreme,
# There lies a magical concept, a developer's dream.
# It's called recursion, a powerful tool indeed,
# In which a function calls itself, with great speed.
#
# Like a mirror reflecting an image endlessly,
# The function repeats its task, tirelessly.
# Through layers of calls, it traverses the stack,
# Solving problems with elegance, never looking back.
#
# Like the branches on a never-ending tree,
# Recursion splits and flourishes, endlessly.
# Breaking down complex tasks into smaller parts,
# It conquers complexity with creative smarts.
#
# But beware, for recursion can be a slippery slope,
# If not carefully managed, it may dash your hope.
# Stack overflow errors, like a relentless foe,
# Remind us to be cautious, as onward we go.
#
# So embrace recursion, but use it with care,
# For in the world of programming, it's truly rare.
# With its beauty and power, it conquers all fears,
# A concept so elegant, it brings joy to coders' ears.
